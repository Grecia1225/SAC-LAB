# %%
count=0
total=0
while count<10:
    n=int(input("enter the number:"))
    total+=n
    count+=1
avg=total/10
print('averag of 10 numbers is :',avg)
# Out:
# enter the number: 1
# enter the number: 2
# enter the number: 3
# enter the number: 4
# enter the number: 5
# enter the number: 6
# enter the number: 7
# enter the number: 8
# enter the number: 9
# enter the number: 7
# averag of 10 numbers is : 5.2
