# %%
marks = [30, 40, 35, 30, 32, 36]
print("Marks are: ", marks)

total = 0

for i in marks:
    total += i

print("Total marks are: ", total)
# Out:
# Marks are:  [30, 40, 35, 30, 32, 36]
# Total marks are:  203
