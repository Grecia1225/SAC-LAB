# %%
# Program:
student = {
    "name": "Amulya",
    "roll no": 103,
    "course": "CSE(AI)-B"
}

print("Dictionary items:")
for key, value in student.items():
    print(key, ":", value)
# Out:
# Dictionary items:
# name : Amulya
# roll no : 103
# course : CSE(AI)-B
