# %%
cent=float(input("enter temp in degree centigrade:"))
#Degree centigrade tofahrenheit
fahrenheit=9/5*cent+32
#degree centigrade=freezing,100 degree centigrade=Boiling->difference=100
#32degree fahreinheit,212 degree fahreineit=Boiling->difference=180
#180/100=9/5 degree fahreinheit
print("the converted temperature is:",fahrenheit)
# Out:
# enter temp in degree centigrade: 5
# the converted temperature is: 41.0
