# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CSV file into a DataFrame
df = pd.read_csv("SAC-marks-30students.csv")
print(df)
# Program:
# Line Plot
df['SAC-THEORY-Marks'].plot(kind="line")
plt.title("Line Plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       4 # Load CSV file into a DataFrame
#       5 df = pd.read_csv("SAC-marks-30students.csv")
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp313-cp313-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp313-cp313-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.0/8.1 MB 1.5 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.1 MB 1.6 MB/s eta 0:00:05
# ...
